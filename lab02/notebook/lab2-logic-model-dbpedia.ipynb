# %% [markdown]
# # Laboratório 2

# %% [markdown]
# ## Tarefa 1
#
# ### Carregue o nó de Tenda dos Milagres (da versão em inglês Tent of Miracles) em Python e mostre o conteúdo JSON.

# %%
import io
import requests
import json

url_drum = "https://dbpedia.org/data/Tent_of_Miracles_(novel).jsod"

data_drum = requests.get(url_drum)
json_drum = data_drum.json()

print(json.dumps(json_drum, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Tent_of_Miracles_(novel)"
#             },
#             "http://www.w3.org/2000/01/rdf-schema#label": "Tent of Miracles (novel)",
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/French_New_Wave"
#                }
#             },
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Modernist_novels"
#                }
#             },
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/ontology/WrittenWork"
#                }
#             },
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:According_to_whom"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#comment": "Tent of Miracles (Portuguese: Tenda dos Milagres) is a Brazilian Modernist novel. It was written by Jorge Amado in 1967 and published the following year. It was later adapted to a 1977 Cinema Novo (Nouvelle Vague) film by director/screenplay writer Nelson Pereira dos Santos.",
#             "http://dbpedia.org/ontology/abstract": "La bottega dei miracoli \u00e8 un romanzo di Jorge Amado pubblicato nel 1960. Come altri romanzi dell&#39;autore (ad esempio Tieta d&#39;Agreste e Teresa Batista) \u00e8 un testo composito, con un intreccio zigzagante fra analessi e prolessi, con mutamenti di voci narranti ed inserti di materiale eterogeneo.\u00c8 possibile che l&#39;evento scatenante del racconto (la visita del famoso scienziato) sia stato ispirato dall&#39;esperienza vissuta; in quello stesso 1960, infatti, Jean Paul Sartre e Simone De Beauvoir visitarono il Brasile su invito dello stesso Amado: la visita divenne un evento mediatico, celebrato in numerose manifestazioni istituzionali.",
#             "http://dbpedia.org/property/pubDate": "1969",
#             "http://dbpedia.org/property/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://rdf.freebase.com/ns/m.02xrs4"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "974212123",
#             "http://dbpedia.org/property/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://dbpedia.org/ontology/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/name": "Tenda dos Milagres",
#             "http://dbpedia.org/property/englishPubDate": "1971",
#             "http://dbpedia.org/ontology/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/property/name": "Tent of Miracles",
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Novel"
#                }
#             },
#             "http://dbpedia.org/property/titleOrig": "Tenda dos Milagres",
#             "http://dbpedia.org/ontology/publisher": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/ontology/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)?oldid=974212123&ns=0"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageLength": "5253",
#             "http://purl.org/dc/elements/1.1/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageID": "623351",
#             "http://dbpedia.org/property/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/caption": "First edition",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)"
#                }
#             }
#          }
#       ],
#       "__count": "1"
#    }
# }

# %% [markdown]
# ## Tarefa 2
# ### Recupere via Python e mostre o autor de Tenda dos Milagres?

# %%
amado = json_drum["d"]["results"][0]["http://dbpedia.org/ontology/author"]["__deferred"]["uri"]
print("Autor de Tenda dos Milagres: " + amado)
# Out:
# Autor de Tenda dos Milagres: http://dbpedia.org/resource/Jorge_Amado

# %%
url_req = "https://dbpedia.org/data/Jorge_Amado.jsod"

data_req = requests.get(url_req)
json_req = data_req.json()

print(json.dumps(json_req, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Jorge_Amado"
#             },
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jubiab\u00e1"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#comment": "Jorge Amado de Faria, n\u00e9 le 10 ao\u00fbt 1912 \u00e0 Itabuna, dans l&#39;\u00c9tat de Bahia, et mort le 6 ao\u00fbt 2001 \u00e0 Salvador, dans l&#39;\u00c9tat de Bahia, est un \u00e9crivain br\u00e9silien de l&#39;\u00e9cole moderniste.",
#             "http://dbpedia.org/ontology/notableWork": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Captains_of_the_Sands"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#label": "Jorge Amado",
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://www.wikidata.org/entity/Q24229398"
#                }
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://de.dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:S-end"
#                }
#             },
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Brazilian_male_novelists"
#                }
#             },
#             "http://dbpedia.org/ontology/abstract": "Jorge Amado, w\u0142a\u015bc. Jorge Leal Amado de Faria (ur. 10 sierpnia 1912 w Pirangi, zm. 6 sierpnia 2001 w Salvador da Bahia) \u2013 brazylijski pisarz , nazywany ojcem stereotypu, najs\u0142ynniejszy dwudziestowieczny brazylijski tw\u00f3rca literatury. Jeden z najbardziej p\u0142odnych powie\u015bciopisarzy wsp\u00f3\u0142czesnych. Jego ksi\u0105\u017cki przeznaczone dla klas ni\u017cszych i kolorowych zosta\u0142y przet\u0142umaczone na siedemdziesi\u0105t j\u0119zyk\u00f3w.",
#             "http://dbpedia.org/property/name": "Jorge Amado",
#             "http://dbpedia.org/property/wordnet_type": {
#                "__deferred": {
#                   "uri": "http://www.w3.org/2006/03/wn/wn20/instances/synset-writer-noun-1"
#                }
#             },
#             "http://dbpedia.org/property/before": "Ot\u00e1vio Mangabeira",
#             "http://dbpedia.org/property/relatives": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/V\u00e9ra_Clouzot"
#                }
#             },
#             "http://dbpedia.org/property/movement": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Modernism"
#                }
#             },
#             "http://dbpedia.org/property/signature": "Jorge Amado Signature.jpg",
#             "http://dbpedia.org/ontology/birthPlace": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Bahia"
#                }
#             },
#             "http://dbpedia.org/property/almaMater": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Federal_University_of_Rio_de_Janeiro_Faculty_of_Law"
#                }
#             },
#             "http://dbpedia.org/property/birthPlace": "Itabuna, Bahia, Brazil",
#             "http://dbpedia.org/ontology/relative": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/V\u00e9ra_Clouzot"
#                }
#             },
#             "http://dbpedia.org/ontology/movement": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Modernism"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageExternalLink": {
#                "__deferred": {
#                   "uri": "https://www.loc.gov/item/93842432/"
#                }
#             },
#             "http://dbpedia.org/property/deathPlace": "Salvador, Bahia, Brazil",
#             "http://dbpedia.org/ontology/birthName": "Jorge Leal Amado de Faria",
#             "http://dbpedia.org/ontology/wikiPageLength": "15728",
#             "http://dbpedia.org/property/occupation": "Writer, professor",
#             "http://dbpedia.org/ontology/spouse": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Z\u00e9lia_Gattai"
#                }
#             },
#             "http://dbpedia.org/ontology/thumbnail": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Special:FilePath/Jorge_Amado.jpg?width=300"
#                }
#             },
#             "http://dbpedia.org/property/after": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Z\u00e9lia_Gattai"
#                }
#             },
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Jorge_Amado?oldid=1021990501&ns=0"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/name": "Jorge Amado",
#             "http://dbpedia.org/property/deathDate": "2001-08-06",
#             "http://xmlns.com/foaf/0.1/depiction": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Special:FilePath/Jorge_Amado.jpg"
#                }
#             },
#             "http://dbpedia.org/property/title": "Brazilian Academy of Letters \u2013 Occupant of the 23rd chair",
#             "http://dbpedia.org/property/birthName": "Jorge Leal Amado de Faria",
#             "http://dbpedia.org/ontology/deathPlace": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Salvador,_Bahia"
#                }
#             },
#             "http://dbpedia.org/property/spouse": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Z\u00e9lia_Gattai"
#                }
#             },
#             "http://dbpedia.org/ontology/deathDate": "2001-08-06",
#             "http://dbpedia.org/property/caption": "Jorge Amado in 1935",
#             "http://schema.org/sameAs": {
#                "__deferred": {
#                   "uri": "http://viaf.org/viaf/108732513"
#                }
#             },
#             "http://dbpedia.org/property/birthDate": "1912-08-10",
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Writer"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "1021990501",
#             "http://dbpedia.org/property/nationality": "Brazilian",
#             "http://dbpedia.org/ontology/wikiPageID": "421320",
#             "http://dbpedia.org/property/notableworks": "Gabriela, Clove and Cinnamon, Dona Flor and Her Two Husbands, Tieta, Captains of the Sands",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Jorge_Amado"
#                }
#             },
#             "http://dbpedia.org/property/years": "1961",
#             "http://dbpedia.org/ontology/birthDate": "1912-08-10",
#             "http://dbpedia.org/ontology/almaMater": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Federal_University_of_Rio_de_Janeiro_Faculty_of_Law"
#                }
#             },
#             "http://dbpedia.org/property/imageSize": "200"
#          }
#       ],
#       "__count": "1"
#    }
# }

# %% [markdown]
# ## Tarefa 3
# ### Quais os termos usados para Aspirina (consulta JSON/MeSH em Python)?

# %%
url_template = "https://id.nlm.nih.gov/mesh/lookup/descriptor?label={concept}&match={match}&limit={limit}"

concept = "Aspirin"
match = "exact"
limit = "10"

concept = concept.replace(" ", "%20")

url = url_template.replace("{concept}", concept)\
                  .replace("{match}", match)\
                  .replace("{limit}", limit)

data = requests.get(url)
json_mi = data.json()

uri_mesh = json_mi[0]["resource"]
bar = str.rindex(uri_mesh, "/")
url_template = "https://id.nlm.nih.gov/mesh/lookup/details?descriptor={code}"

code = uri_mesh[bar+1:]

url = url_template.replace("{code}", code)

data = requests.get(url)
json_mid = data.json()
print(json.dumps(json_mid, indent=3))
# Out:
# {
#    "descriptor": "http://id.nlm.nih.gov/mesh/D001241",
#    "terms": [
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003713",
#          "label": "Aspirin",
#          "preferred": true
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003714",
#          "label": "2-(Acetyloxy)benzoic Acid",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003712",
#          "label": "Acetylsalicylic Acid",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003721",
#          "label": "Acetysal",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003722",
#          "label": "Acylpyrin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003711",
#          "label": "Aloxiprimum",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003723",
#          "label": "Colfarit",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003715",
#          "label": "Dispril",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003719",
#          "label": "Easprin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003724",
#          "label": "Ecotrin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003725",
#          "label": "Endosprin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003726",
#          "label": "Magnecyl",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003727",
#          "label": "Micristin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003717",
#          "label": "Polopirin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003728",
#          "label": "Polopiryna",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003716",
#          "label": "Solprin",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003718",
#          "label": "Solupsan",
#          "preferred": false
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/T003720",
#          "label": "Zorprin",
#          "preferred": false
#       }
#    ],
#    "qualifiers": [
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000008",
#          "label": "administration & dosage"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000009",
#          "label": "adverse effects"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000819",
#          "label": "agonists"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000031",
#          "label": "analogs & derivatives"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000032",
#          "label": "analysis"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000037",
#          "label": "antagonists & inhibitors"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000097",
#          "label": "blood"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000134",
#          "label": "cerebrospinal fluid"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000138",
#          "label": "chemical synthesis"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000737",
#          "label": "chemistry"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000145",
#          "label": "classification"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000191",
#          "label": "economics"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000266",
#          "label": "history"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000276",
#          "label": "immunology"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000302",
#          "label": "isolation & purification"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000378",
#          "label": "metabolism"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000493",
#          "label": "pharmacokinetics"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000494",
#          "label": "pharmacology"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000506",
#          "label": "poisoning"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000528",
#          "label": "radiation effects"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000592",
#          "label": "standards"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000600",
#          "label": "supply & distribution"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000627",
#          "label": "therapeutic use"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000633",
#          "label": "toxicity"
#       },
#       {
#          "resource": "http://id.nlm.nih.gov/mesh/Q000652",
#          "label": "urine"
#       }
#    ],
#    "seealso": []
# }

# %% [markdown]
# ## Tarefa 4
# ### Escolha algum lugar no OpenStreetMap e elabore a mesma sequência de três chamadas de serviços para o seu conceito.

# %%
url_template = "http://nominatim.openstreetmap.org/search?format={format}&q={query}"
format = "json"
query = "Beverly Center"

url = url_template.replace("{format}", format)\
                  .replace("{query}", query)

data = requests.get(url)
beverly_ref = data.json()
print(json.dumps(beverly_ref, indent=3))
# Out:
# [
#    {
#       "place_id": 99471815,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 31369157,
#       "boundingbox": [
#          "34.073545",
#          "34.0763036",
#          "-118.3792396",
#          "-118.3767002"
#       ],
#       "lat": "34.07502375",
#       "lon": "-118.3772791792705",
#       "display_name": "Beverly Center, South San Vicente Boulevard, Beverly Grove, Los Angeles, California, 90048, United States",
#       "class": "shop",
#       "type": "mall",
#       "importance": 0.537269171634054
#    },
#    {
#       "place_id": 94142303,
#       "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#       "osm_type": "way",
#       "osm_id": 23547040,
#       "boundingbox": [
#          "33.7197781",
#          "33.7204983",
#          "73.0733782",
#          "73.0743424"
#       ],
#       "lat": "33.720138250000005",
#       "lon": "73.07386030243109",
#       "display_name": "Beverly Center, Service Road South F-6; Service Road West F-6, \u0627\u06cc\u0641-6, Blue Area, 4400, \u067e\u0627\u06a9\u0633\u062a\u0627\u0646",
#       "class": "building",
#       "type": "yes",
#       "importance": 0.201
#    }
# ]

# %%
print(beverly_ref[0]["osm_id"])
# Out:
# 31369157

# %%
url_template = "https://api.openstreetmap.org/api/0.6/{element_type}/{id}.{format}"

element_type = "way" # types: node, way, or relation
id = str(beverly_ref[0]["osm_id"])
format = "json"

url = url_template.replace("{element_type}", element_type)\
                  .replace("{id}", id)\
                  .replace("{format}", format)

data = requests.get(url)
beverly_way = data.json()
print(json.dumps(beverly_way, indent=3))
# Out:
# {
#    "version": "0.6",
#    "generator": "CGImap 0.8.5 (2367631 spike-08.openstreetmap.org)",
#    "copyright": "OpenStreetMap and contributors",
#    "attribution": "http://www.openstreetmap.org/copyright",
#    "license": "http://opendatacommons.org/licenses/odbl/1-0/",
#    "elements": [
#       {
#          "type": "way",
#          "id": 31369157,
#          "timestamp": "2018-04-24T09:37:23Z",
#          "version": 8,
#          "changeset": 58367756,
#          "user": "Edward",
#          "uid": 364,
#          "nodes": [
#             349340421,
#             1718692863,
#             349340424,
#             1718692865,
#             349340426,
#             349340428,
#             349340430,
#             349340432,
#             349340434,
#             349340436,
#             349340438,
#             349340441,
#             349340444,
#             349340446,
#             349340448,
#             349340449,
#             349340450,
#             1718692864,
#             5185096599,
#             349340451,
#             1718692857,
#             5185096998,
#             349340452,
#             349340453,
#             349340454,
#             349340455,
#             1718692847,
#             349340456,
#             349340421
#          ],
#          "tags": {
#             "building": "yes",
#             "building:levels": "3",
#             "ele": "96.2",
#             "height": "46.6",
#             "lacounty:ain": "4334007008;4334007009",
#             "lacounty:bld_id": "447470850115;447330849697",
#             "name": "Beverly Center",
#             "shop": "mall",
#             "start_date": "1981",
#             "wikidata": "Q4899491"
#          }
#       }
#    ]
# }
